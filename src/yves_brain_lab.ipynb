# %%
# %load_ext autoreload
# %autoreload 2

import os
from engine import YvesEngine
from identity import YvesIdentity 
from coder import Coder
from retriever import MemoryVault, YvesRetriever  # Imported the orchestrator
from history_manager import HistoryManager 

# 1. Load absolute workspace configuration paths
from config_loader import YvesConfig
config = YvesConfig()

# 2. Synchronise your local codebase files into ChromaDB
# This scans your folders and ensures the search context is never empty
retriever = YvesRetriever(inventory_dir=config.INVENTORY_DIR, memory_dir=config.MEMORY_DIR)
retriever.sync_inventory()

# 3. Initialize core components using config paths
identity_component = YvesIdentity(model_name=config.PERSONALITY_MODEL)
coder_component = Coder(model_name=config.LOGIC_MODEL)
vault_component = MemoryVault(memory_path=config.MEMORY_DIR) 
history_component = HistoryManager(max_limit=10) 

# 4. Inject dependencies into the engine
yves = YvesEngine(
    identity=identity_component, 
    coder=coder_component, 
    vault=vault_component, 
    history=history_component
)

print("Yves is online, fully synced, and localized.")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Yves is online, fully synced, and localized.

# %%
user_query = "Hey Yves, check my engine file logic. Does the route_intent method cover enough keywords or should we move to an embedding check?"
response = yves.ask(user_query)

print(f"Yves: {response}")
# Out:
# Yves: The query from Dustin, no doubt about it. I've taken a glance at your route_intent method in your engine file. (pausing for a brief moment)
#
# It appears that the current implementation has some limitations in terms of keyword coverage. The method only checks for specific phrases related to "search" and "book," but these might not be sufficient to handle all possible intents.
#
# Upon closer inspection, I notice that there are no intent categories defined beyond "search" and "book." This could lead to inconsistencies if you need to accommodate new or complex user queries. The method's keyword lists also rely on hardcoded values, which may not be ideal for real-world applications where context might play a significant role.
#
# Now, considering the proposed steps I provided earlier... (pausing once more)
#
# It seems that an embedding check could indeed provide a better solution here. By leveraging pre-trained transformer models and their associated embeddings, you can capture semantic meaning in user queries more effectively. This would allow for more nuanced handling of complex or ambiguous queries.
#
# To implement this approach, I'd recommend using libraries like `scikit-learn` or `transformers` from Hugging Face to load pre-trained models and perform the necessary computations. The example code provided earlier demonstrates how you can create a basic embedding-based route_intent method using a pre-trained transformer model.
#
# Before proceeding, I'd advise reviewing the intent classification approach and ensuring that the embeddings are properly aligned with your application's requirements. This might involve fine-tuning the pre-trained model or creating custom models tailored to your specific needs.
#
# In summary, it seems that an embedding check could be a suitable solution to enhance the coverage of potential intents in your route_intent method. Shall we proceed with exploring this option further?
